# %% [markdown]
# # Connecting to Data Sources to get data

# %% [markdown]
# Thus far we have connected to an api to get stock information- however with each of the data sources that we've mentioned there are python connectors.
# As with everything in python- the first thing that we'll want to check before connecting to anything is whether or not someone else has done the work for us.
# To connect to an api we utilized a library called "google finance".
# Let's see if there's a way to do something similar with, for example, a csv.
# Everyone download the csv that we have in this folder.

# %%
import csv

# %%
with open('PART_I_CRIMES.csv', 'r') as f:
    crimes=csv.reader(f)
    for each in crimes:
        print each
# Out:
# ['LURN_SAK', 'INCIDENT_DATE', 'STAT', 'STAT_DESC', 'STREET', 'CITY', 'ZIP', 'XY_POINT', 'INCIDENT_ID', 'REPORTING_DISTRICT', 'SEQ', 'UNIT_ID', 'UNIT_NAME', 'DELETED']
# ['17545426', '2015-11-09 03:00:00', '011', 'CRIMINAL HOMICIDE: Murder', '11000 HAWTHORNE BLVD', 'LENNOX', '90304', '6454618.6800413253,1798826.3041394814', '015-09855-0383', '0383', '09855', 'CA0190003', 'SOUTH LOS ANGELES', 'N']
# ['17544618', '2015-11-07 21:41:00', '011', 'CRIMINAL HOMICIDE: Murder', '1000 W 92ND ST', 'LOS ANGELES', '90044', '6472819.9467580942,1805594.358132056', '015-09821-0370', '0370', '09821', 'CA0190003', 'SOUTH LOS ANGELES', 'N']
# ['17540570', '2015-11-04 05:35:00', '011', 'CRIMINAL HOMICIDE: Murder', '400 BAUCHET ST', 'LOS ANGELES', '90012', '6491680.1146679176,1843985.3207699372', '015-03939-5800', '5800', '03939', 'CA01900U2', 'TTCF', 'N']
# ['17537986', '2015-11-01 00:03:00', '011', 'CRIMINAL HOMICIDE: Murder', '9700 PAR PL', 'PICO RIVERA', '90660', '6542765.8665802078,1827854.5830498398', '015-80055-1511', '1511', '80055', 'CA0190015', 'PICO RIVERA', 'N']
# ['17538449', '2015-10-31 22:45:00', '011', 'CRIMINAL HOMICIDE: Murder', '16100 BELLFLOWER BLVD', 'BELLFLOWER', '', '6523669.2071592649,1781896.0954597325', '015-80156-1337', '1337', '80156', 'CA0190013', 'LAKEWOOD', 'N']
# ['17535825', '2015-10-30 08:45:41', '011', 'CRIMINAL HOMICIDE: Murder', '', '', '', '', '015-15736-2607', '2607', '15736', 'CA01900W9', 'PALMDALE', 'N']
# ['17535688', '2015-10-30 01:25:00', '011', 'CRIMINAL HOMICIDE: Murder', '16800 BELLBROOK ST', 'COVINA', '91722', '6586691.8551210603,1858235.8616379115', '015-05078-0866', '0866', '05078', 'CA0190008', 'SAN DIMAS', 'N']
# ['17531297', '2015-10-25 19:00:00', '011', 'CRIMINAL HOMICIDE: Murder', 'LINCOLN AVE & SHRODE AVE', 'MONROVIA', '91016', '6563385,1866712.249996', '015-12591-0583', '0583', '12591', 'CA0190005', 'TEMPLE', 'N']
# ['17530837', '2015-10-25 03:50:00', '011', 'CRIMINAL HOMICIDE: Murder', '400 WASHINGTON BLVD', 'MARINA DEL REY', '', '6421200.312982,1815820.309811', '015-02953-2760', '2760', '02953', 'CA0190065', 'MARINA DEL REY', 'N']
# ['17530210', '2015-10-24 08:38:00', '011', 'CRIMINAL HOMICIDE: Murder', '36200 PARADISE RANCH RD', 'CASTAIC', '91384', '6353897.6149550136,2031718.2419695416', '015-14374-0689', '0689', '14374', 'CA0190006', 'SANTA CLARITA VALLEY', 'N']
# ['
# ['17508299', '2015-10-12 22:00:00', '023', 'RAPE BY FORCE, FEMALE UNDER 18', '1300 E AVENUE I', 'LANCASTER', '93535', '6529819.2792026699,2080228.8206543666', '015-18179-1131', '1131', '18179', 'CA0190024', 'LANCASTER', 'N']
# ['17504978', '2015-10-12 04:45:00', '023', 'RAPE BY FORCE, FEMALE UNDER 18', '19400 STILLMORE ST', 'CANYON COUNTRY', '91351', '6418497.3802187638,1974966.5377640931', '015-13828-0612', '0612', '13828', 'CA0190006', 'SANTA CLARITA VALLEY', 'N']
# ['17543452', '2015-11-06 13:44:00', '025', 'RAPE BY FORCE, MALE 18 AND OVER', '800 N ALAMEDA ST', 'LOS ANGELES', '', '6489722.3367786147,1842461.2344891792', '015-06432-6901', '6901', '06432', 'CA0190031', 'TRANSIT SERV BUR', 'N']
# ['17529040', '2015-10-23 01:00:00', '025', 'RAPE BY FORCE, MALE 18 AND OVER', 'BENFIELD AVE', 'NORWALK', '90650', '', '015-14085-0455', '0455', '14085', 'CA0190004', 'NORWALK', 'N']
# ['17540911', '2015-10-29 21:00:00', '027', 'RAPE BY FORCE, MALE UNDER 18', '6000 STARVIEW DR', 'LANCASTER', '93536', '6490079.9989707228,2070406.2991476981', '015-19648-1122', '1122', '19648', 'CA0190024', 'LANCASTER', 'N']

# %% [markdown]
# So we know that we can read files! Now that we have this data available in python we can do a lot of different stuff with it- write it to another file, put it in a database, display it...whatever! (Hint: You can use "csv.writer" to write it to a new file....AND if you would like- you can then EMAIL that file using the "smtp" library- which we can optionally go over later.
# So what about a SQL database (VERY common!). Let's connect to a REDSHIFT database!
# To do this we will need to get a library called psycopg2 (python's redshift connector).

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in /Users/fpombeiro/anaconda2/lib/python2.7/site-packages

# %%
import psycopg2

# %% [markdown]
# Now- to connect to a database we need an address (like a website). There is a file in this folder to connect to General Assembly's redshift instance. Grab that.
#
#
# Here is the relevant data:
# host:
#
# West-coast (includes Austin and Chicago)
# analyticsga.cuwj8wuu6wbh.us-west-2.rds.amazonaws.com
#
# port: 5432
# username: analytics_student
# password: analyticsga
#
# So assign each of these attributes to variables

# %%
host = 'analyticsga.cuwj8wuu6wbh.us-west-2.rds.amazonaws.com'
database = 'iowa_liquor_sales_database'
port = 5432
username = 'analytics_student'
password = 'analyticsga'

# %% [markdown]
# ...and now we're going to *actually* connect to the database with something called a "connection string". This is where we pass the information into a variable (object). Now remember- the object.method relationship here. So now we're connected...

# %%
con=psycopg2.connect(dbname= database, host=host, 
port= port, user= username, password= password)

# %% [markdown]
# Now we're going to create a "cursor" (read "pointer") and attach it.

# %%
cur = con.cursor()

# %% [markdown]
# Okay! We're ready to run some SQL (structured query language) against our database! Let's run that quickly and we get...

# %%
cur.execute('SELECT * FROM products limit 1000;')

# %% [markdown]
# So what we're doing here is running a query against the "iowa liquor sales database" and returning everything in that table (SQL tables are basically giant excel spreadsheets). In this next command we will fetch the data and then show it.

# %%
liquor = cur.fetchall()

# %%
liquor
# Out:
# [(904616,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Travis Hasse Apple Pie',
#   305,
#   'Mhw Ltd',
#   750,
#   12,
#   1,
#   None,
#   '40',
#   datetime.datetime(2009, 2, 11, 0, 0),
#   None,
#   None,
#   '$9.77',
#   Decimal('14.66'),
#   Decimal('117.22')),
#  (904617,
#   'MISC. IMPORTED CORDIALS & LIQUEURS',
#   "D'aristi Xtabentun",
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   12,
#   1,
#   None,
#   '60',
#   datetime.datetime(2009, 4, 24, 0, 0),
#   None,
#   None,
#   '$14.12',
#   Decimal('21.18'),
#   Decimal('169.40')),
#  (904618,
#   'PEACH BRANDIES',
#   'Hiram Walker Peach Brandy',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1000,
#   12,
#   1,
#   None,
#   '60',
#   datetime.datetime(2009, 12, 16, 0, 0),
#   None,
#   '89540500867',
#   '$6.50',
#   Decimal('9.74'),
#   Decimal('77.94')),
#  (904619,
#   'SCOTCH WHISKIES',
#   'Oak Cross Whisky',
#   305,
#   'Mhw Ltd',
#   750,
#   6,
#   1,
#   None,
#   '86',
#   datetime.datetime(2009, 12, 24, 0, 0),
#   None,
#   None,
#   '$25.33',
#   Decimal('38.00'),
#   Decimal('152.00')),
#  (904620,
#   'FLAVORED VODKA',
#   'Uv Red(cherry) Vodka',
#   380,
#   'Phillips Beverage Company',
#   200,
#   24,
#   1,
#   None,
#   '60',
#   datetime.datetime(2009, 11, 5, 0, 0),
#   None,
#   '10087100000000',
#   '$1.97',
#   Decimal('2.96'),
#   Decimal('47.30')),
#  (904621,
#   'STRAIGHT BOURBON WHISKIES',
#   'Heaven Hill Old Style White Label',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 12, 4, 0, 0),
#   None,
#   None,
#   '$6.37',
#   Decimal('9.55'),
#   Decimal('76.40')),
#  (904622,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Hyde Herbal Liqueur',
#   194,
#   'Fire Tail Brands Llc',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 5, 0, 0),
#   None,
#   '904622',
#   '$5.06',
#   Decimal('7.59'),
#   Decimal('60.70')),
#  (904623,
#   'MISCELLANEOUS BRANDIES',
#   'Dupont Calvados Fine Reserve',
#   403,
#   'Robert Kacher Selections',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 12, 24, 0, 0),
#   None,
#   None,
#   '$23.61',
#   Decimal('35.42'),
#   Decimal('283.33')),
#  (904624,
#   'IMPORTED VODKA',
#   'Sobieski Cytron Vodka',
#   267,
#   'Imperial Brands Inc.',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 12, 29, 0, 0),
#   None,
#   '10089000000000',
#   '$5.69',
#   Decimal('8.54'),
#   Decimal('68.32')),
#  (904625,
#   'FLAVORED RUM',
#   'Captain Morgan Parrot Bay Strawberry',
#   260,
#   'Diageo Americas',
#   750,
#   12,
#   1,
#   None,
#   '42',
#   datetime.datetime(2010, 1, 12, 0, 0),
#   None,
#   '82000756835',
#   '$7.49',
#   Decimal('11.24'),
#   Decimal('89.84')),
#  (904626,
#   'SINGLE MALT SCOTCH',
#   'Arran 10yr',
#   10,
#   'A Hardy / U.s.a. Ltd.',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2009, 10, 1, 0, 0),
#   None,
#   None,
#   '$25.83',
#   Decimal('38.75'),
#   Decimal('155.00')),
#  (904627,
#   'FLAVORED RUM',
#   'Malibu Tropical Banana',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1000,
#   12,
#   1,
#   None,
#   '42',
#   datetime.datetime(2009, 6, 10, 0, 0),
#   '89540493367',
#   None,
#   '$9.16',
#   Decimal('13.74'),
#   Decimal('109.95')),
#  (904628,
#   'SCOTCH WHISKIES',
#   'Ballantines Finest',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 1, 12, 0, 0),
#   None,
#   None,
#   '$21.93',
#   Decimal('32.90'),
#   Decimal('131.59')),
#  (904629,
#   'DISTILLED SPIRITS SPECIALTY',
#   'Catdaddy Carolina Moonshine',
#   384,
#   'Piedmont Distillers',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 1, 20, 0, 0),
#   None,
#   '10851800000000',
#   '$12.08',
#   Decimal('18.13'),
#   Decimal('72.50')),
#  (904630,
#   'STRAIGHT BOURBON WHISKIES',
#   'Early Times Mint Julep',
#   85,
#   'Brown-forman Corporation',
#   1000,
#   12,
#   1,
#   None,
#   '60',
#   datetime.datetime(2010, 1, 25, 0, 0),
#   '81128010904',
#   '904630',
#   '$7.94',
#   Decimal('11.91'),
#   Decimal('95.25')),
#  (904631,
#   'IMPORTED DRY GINS',
#   'Tanqueray Gin Mini',
#   260,
#   'Diageo Americas',
#   502,
#   12,
#   1,
#   None,
#   '94',
#   datetime.datetime(2010, 1, 12, 0, 0),
#   None,
#   '88076175099',
#   '$14.54',
#   Decimal('21.81'),
#   Decimal('174.51')),
#  (904632,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Hiram Walker Creme De Strawberry',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1000,
#   12,
#   1,
#   None,
#   '30',
#   datetime.datetime(2010, 1, 26, 0, 0),
#   None,
#   None,
#   '$4.50',
#   Decimal('6.75'),
#   Decimal('53.94')),
#  (904633,
#   'FLAVORED VODKA',
#   "Seagram's Wild Grape Vodka",
#   255,
#   'Wilson Daniels Ltd.',
#   200,
#   24,
#   1,
#   None,
#   '70',
#   datetime.datetime(2009, 2, 24, 0, 0),
#   '720816000000',
#   '20720800000000',
#   '$1.01',
#   Decimal('1.52'),
#   Decimal('24.21')),
#  (904634,
#   'AMERICAN COCKTAILS',
#   "Seagram's Ruby Red Grapfruit Gin & Juice",
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   375,
#   12,
#   1,
#   None,
#   '35',
#   datetime.datetime(2009, 10, 7, 0, 0),
#   None,
#   None,
#   '$2.40',
#   Decimal('3.60'),
#   Decimal('28.83')),
#  (904635,
#   'IMPORTED VODKA',
#   'Grey Goose La Poire Vodka(pear)',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 5, 15, 0, 0),
#   None,
#   '20080500000000',
#   '$18.49',
#   Decimal('27.74'),
#   Decimal('110.94')),
#  (904636,
#   'DISTILLED SPIRITS SPECIALTY',
#   'Virginia Moonshine',
#   68,
#   'Belmont Farms Of Va. Inc',
#   750,
#   12,
#   1,
#   None,
#   '100',
#   datetime.datetime(2010, 1, 26, 0, 0),
#   None,
#   None,
#   '$11.84',
#   Decimal('17.76'),
#   Decimal('142.06')),
#  (904637,
#   'IMPORTED VODKA',
#   'Sobieski Cytron Vodka',
#   267,
#   'Imperial Brands Inc.',
#   1000,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2009, 12, 30, 0, 0),
#   '89016009146',
#   '904637',
#   '$7.05',
#   Decimal('10.58'),
#   Decimal('84.60')),
#  (904638,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Dekuyper Lemon Drop',
#   65,
#   'Jim Beam Brands',
#   750,
#   12,
#   1,
#   None,
#   '40',
#   datetime.datetime(2010, 1, 27, 0, 0),
#   None,
#   '10080700000000',
#   '$6.30',
#   Decimal('9.45'),
#   Decimal('75.60')),
#  (904639,
#   'IMPORTED GRAPE BRANDIES',
#   'Tosolini Cividina Grappa',
#   338,
#   'Niche Import Co.',
#   1000,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 1, 0, 0),
#   None,
#   None,
#   '$16.83',
#   Decimal('25.25'),
#   Decimal('101.00')),
#  (904640,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Dekuyper Alabama Slammer',
#   65,
#   'Jim Beam Brands',
#   750,
#   12,
#   1,
#   None,
#   '40',
#   datetime.datetime(2010, 1, 27, 0, 0),
#   None,
#   None,
#   '$6.30',
#   Decimal('9.45'),
#   Decimal('75.60')),
#  (904641,
#   'SINGLE MALT SCOTCH',
#   'Glenrothes Triple Double',
#   461,
#   'Campari(skyy)',
#   301,
#   12,
#   1,
#   None,
#   '86',
#   datetime.datetime(2010, 1, 29, 0, 0),
#   None,
#   None,
#   '$15.50',
#   Decimal('23.25'),
#   Decimal('186.00')),
#  (904642,
#   'MISC. IMPORTED CORDIALS & LIQUEURS',
#   'Nassau Royale',
#   35,
#   'Bacardi U.s.a. Inc.',
#   1000,
#   12,
#   1,
#   None,
#   '68',
#   datetime.datetime(2010, 2, 2, 0, 0),
#   None,
#   '10080500000000',
#   '$9.35',
#   Decimal('14.03'),
#   Decimal('112.15')),
#  (904643,
#   'PUERTO RICO & VIRGIN ISLANDS RUM',
#   'Brugal Extra Veijo Rum',
#   305,
#   'Mhw Ltd',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 2, 0, 0),
#   None,
#   '10087200000000',
#   '$12.53',
#   Decimal('18.80'),
#   Decimal('150.32')),
#  (904644,
#   'PEPPERMINT SCHNAPPS',
#   'Ice 101',
#   298,
#   'White Rock Distilleries Inc.',
#   375,
#   24,
#   1,
#   None,
#   '101',
#   datetime.datetime(2009, 7, 29, 0, 0),
#   '89708003537',
#   None,
#   '$4.77',
#   Decimal('7.16'),
#   Decimal('114.45')),
#  (904645,
#   'IMPORTED VODKA',
#   'Ketel One Citoen',
#   260,
#   'Diageo Americas',
#   1000,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 2, 0, 0),
#   None,
#   '10085200000000',
#   '$16.47',
#   Decimal('24.71'),
#   Decimal('197.62')),
#  (904646,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Sharkwater DNO',
#   89,
#   'Temperance Distiling Company',
#   750,
#   12,
#   1,
#   None,
#   '40',
#   datetime.datetime(2009, 2, 11, 0, 0),
#   '94922114464',
#   '10094900000000',
#   '$10.71',
#   Decimal('16.07'),
#   Decimal('128.53')),
#  (904647,
#   'IMPORTED VODKA',
#   'Belvedere Citrus',
#   420,
#   'Moet Hennessy Usa Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 4, 0, 0),
#   None,
#   None,
#   '$17.15',
#   Decimal('25.73'),
#   Decimal('102.90')),
#  (904648,
#   'IMPORTED VODKA',
#   'Fris Grape Vodka',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   '10080400000000',
#   '$5.13',
#   Decimal('7.70'),
#   Decimal('61.50')),
#  (904649,
#   'SINGLE MALT SCOTCH',
#   'Lonach Blended Scotch 1973 36yr',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '82',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   '841119000000',
#   '10841100000000',
#   '$73.00',
#   Decimal('109.50'),
#   Decimal('73.00')),
#  (904650,
#   'IMPORTED VODKA',
#   'Fris Cherry Vodka',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   '10080400000000',
#   '$5.13',
#   Decimal('7.70'),
#   Decimal('61.50')),
#  (904651,
#   'WHISKEY LIQUEUR',
#   'Jeremiah Weed Cherry Mash Blended Bourbon',
#   260,
#   'Diageo Americas',
#   750,
#   12,
#   1,
#   None,
#   '90',
#   datetime.datetime(2010, 2, 10, 0, 0),
#   None,
#   None,
#   '$8.92',
#   Decimal('13.38'),
#   Decimal('107.03')),
#  (904652,
#   'MISC. IMPORTED CORDIALS & LIQUEURS',
#   'Aperol',
#   461,
#   'Campari(skyy)',
#   750,
#   6,
#   1,
#   None,
#   '22',
#   datetime.datetime(2010, 2, 11, 0, 0),
#   None,
#   '70086800000000',
#   '$12.25',
#   Decimal('18.38'),
#   Decimal('73.50')),
#  (904653,
#   'SINGLE MALT SCOTCH',
#   'Benriach Mini Gift Pack Peated',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   502,
#   12,
#   1,
#   None,
#   '89',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   None,
#   '$19.58',
#   Decimal('29.37'),
#   Decimal('235.00')),
#  (904654,
#   'AMERICAN COCKTAILS',
#   'Colonial Club Long Island Ice Tea',
#   350,
#   'Luxco-cleveland',
#   750,
#   12,
#   1,
#   None,
#   '42',
#   datetime.datetime(2010, 2, 16, 0, 0),
#   None,
#   None,
#   '$3.25',
#   Decimal('4.87'),
#   Decimal('38.94')),
#  (904655,
#   'SCOTCH WHISKIES',
#   'Dt Caol Lla 26yr 1982',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '107',
#   datetime.datetime(2010, 2, 16, 0, 0),
#   None,
#   None,
#   '$105.00',
#   Decimal('157.50'),
#   Decimal('105.00')),
#  (904656,
#   'SINGLE MALT SCOTCH',
#   'Springbank 11yr Madeira Wood',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '110',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   None,
#   '$59.00',
#   Decimal('88.50'),
#   Decimal('59.00')),
#  (904657,
#   'IMPORTED VODKA',
#   'Fris Blueberry Vodka',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   '10080400000000',
#   '$5.13',
#   Decimal('7.70'),
#   Decimal('61.50')),
#  (904658,
#   '80 PROOF VODKA',
#   "Tito's Vodka",
#   301,
#   'Fifth Generation Inc.',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 11, 0, 0),
#   None,
#   None,
#   '$18.51',
#   Decimal('27.77'),
#   Decimal('111.08')),
#  (904659,
#   'SINGLE MALT SCOTCH',
#   'Benriach 1976 30yr Port Pipe Cask',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '111',
#   datetime.datetime(2010, 2, 16, 0, 0),
#   None,
#   None,
#   '$205.85',
#   Decimal('308.78'),
#   Decimal('205.85')),
#  (904660,
#   'SCOTCH WHISKIES',
#   'Dt Ror 1982 Linglithgow 21yr Cask',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '127',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   None,
#   '$115.00',
#   Decimal('172.50'),
#   Decimal('115.00')),
#  (904661,
#   'FLAVORED VODKA',
#   'Uv Cherry(red) Vodka Glass',
#   380,
#   'Phillips Beverage Company',
#   200,
#   24,
#   1,
#   None,
#   '60',
#   datetime.datetime(2009, 5, 1, 0, 0),
#   '87116014961',
#   None,
#   '$1.40',
#   Decimal('2.10'),
#   Decimal('33.50')),
#  (904662,
#   'SINGLE MALT SCOTCH',
#   'Longrow Cv',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   None,
#   '$34.18',
#   Decimal('51.27'),
#   Decimal('34.18')),
#  (904663,
#   'SCOTCH WHISKIES',
#   'Dt 1970 Glen Grant 37yr Sherry',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '103',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   None,
#   '$173.50',
#   Decimal('260.25'),
#   Decimal('173.50')),
#  (904664,
#   'SINGLE MALT SCOTCH',
#   'Hazelburn 12 Yr',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   None,
#   '$59.00',
#   Decimal('88.50'),
#   Decimal('59.00')),
#  (904665,
#   'SCOTCH WHISKIES',
#   'Dt Lonach Glendarroch 1966 42yr',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '83',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   None,
#   '$102.00',
#   Decimal('153.00'),
#   Decimal('102.00')),
#  (904666,
#   'SINGLE MALT SCOTCH',
#   'Killerran',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 2, 8, 0, 0),
#   None,
#   None,
#   '$38.00',
#   Decimal('57.00'),
#   Decimal('38.00')),
#  (904667,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Travis Hasse Cherry Pie Liqueur',
#   305,
#   'Mhw Ltd',
#   750,
#   12,
#   1,
#   None,
#   '30',
#   datetime.datetime(2009, 10, 23, 0, 0),
#   None,
#   None,
#   '$8.00',
#   Decimal('12.00'),
#   Decimal('96.00')),
#  (904668,
#   'BLENDED WHISKIES',
#   'Hirsch Selection 20yr',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '96',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   None,
#   None,
#   '$50.00',
#   Decimal('75.00'),
#   Decimal('50.00')),
#  (904669,
#   'TEQUILA',
#   'Aha Toro Anejo Tequila',
#   241,
#   'William Ryan Select Ltd',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 7, 31, 0, 0),
#   None,
#   None,
#   '$32.75',
#   Decimal('49.13'),
#   Decimal('196.48')),
#  (904670,
#   'TEQUILA',
#   'Aha Toro Reposado Tequila',
#   241,
#   'William Ryan Select Ltd',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 7, 31, 0, 0),
#   None,
#   None,
#   '$30.36',
#   Decimal('45.54'),
#   Decimal('182.17')),
#  (904671,
#   'SINGLE MALT SCOTCH',
#   'Benriach Mini Gift Pack Classic',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   502,
#   12,
#   1,
#   None,
#   '84',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   None,
#   '$17.58',
#   Decimal('26.37'),
#   Decimal('211.00')),
#  (904672,
#   'SINGLE MALT SCOTCH',
#   'Dt 1968 Glenlivet 39yo Cask #2831',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '89',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   None,
#   '$160.00',
#   Decimal('240.00'),
#   Decimal('160.00')),
#  (904673,
#   'STRAIGHT BOURBON WHISKIES',
#   'Hirsch Kentucky Straight Corn Whiskey',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '90',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   None,
#   None,
#   '$20.84',
#   Decimal('31.26'),
#   Decimal('20.84')),
#  (904674,
#   'CANADIAN WHISKIES',
#   'Hirsch 8yr Canadian Rye Whiskey',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '86',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   None,
#   None,
#   '$27.00',
#   Decimal('40.50'),
#   Decimal('27.00')),
#  (904675,
#   'SINGLE MALT SCOTCH',
#   'Benriach Curiositas 10yr Single Malt',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   None,
#   None,
#   '$33.93',
#   Decimal('50.90'),
#   Decimal('33.93')),
#  (904676,
#   'TEQUILA',
#   'Aha Toro Blanco Tequila',
#   241,
#   'William Ryan Select Ltd',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 7, 31, 0, 0),
#   None,
#   None,
#   '$27.98',
#   Decimal('41.97'),
#   Decimal('167.86')),
#  (904677,
#   'STRAIGHT BOURBON WHISKIES',
#   'Hirsch Straight Bourbon Small Batch',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   None,
#   None,
#   '$22.00',
#   Decimal('33.00'),
#   Decimal('22.00')),
#  (904678,
#   'SCOTCH WHISKIES',
#   'Grand Macnish',
#   495,
#   'M.s. Walker Inc.',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 8, 20, 0, 0),
#   '89552910401',
#   '30089600000000',
#   '$5.58',
#   Decimal('8.38'),
#   Decimal('67.00')),
#  (904679,
#   'SINGLE MALT SCOTCH',
#   'Benriach Single Malt 16yr',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   None,
#   None,
#   '$55.00',
#   Decimal('82.50'),
#   Decimal('55.00')),
#  (904680,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Francesca Hazelnut',
#   298,
#   'White Rock Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '42',
#   datetime.datetime(2010, 2, 9, 0, 0),
#   None,
#   None,
#   '$4.62',
#   Decimal('6.93'),
#   Decimal('55.45')),
#  (904681,
#   'WATERMELON SCHNAPPS',
#   'Dekuyper Watermelon Pucker Mini',
#   65,
#   'Jim Beam Brands',
#   502,
#   120,
#   1,
#   None,
#   '30',
#   datetime.datetime(2009, 5, 29, 0, 0),
#   '80686396901',
#   None,
#   '$0.52',
#   Decimal('0.78'),
#   Decimal('62.72')),
#  (904682,
#   'DISTILLED SPIRITS SPECIALTY',
#   'Plymouth Sloe Gin',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   750,
#   6,
#   1,
#   None,
#   '52',
#   datetime.datetime(2010, 2, 23, 0, 0),
#   None,
#   '652080000000',
#   '$12.56',
#   Decimal('18.84'),
#   Decimal('75.38')),
#  (904683,
#   'MISCELLANEOUS SCHNAPPS',
#   '99 Oranges',
#   55,
#   'Sazerac North America',
#   750,
#   12,
#   1,
#   None,
#   '99',
#   datetime.datetime(2010, 2, 24, 0, 0),
#   None,
#   '80660118864',
#   '$8.90',
#   Decimal('13.35'),
#   Decimal('106.80')),
#  (904684,
#   'SCOTCH WHISKIES',
#   'Hudson Bay Scotch Whisky',
#   192,
#   'Sidney Frank Importing Co.',
#   1000,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 25, 0, 0),
#   None,
#   None,
#   '$7.40',
#   Decimal('11.10'),
#   Decimal('88.74')),
#  (904685,
#   'TEQUILA',
#   'Centinela Blanco',
#   256,
#   'Haas Brothers',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 5, 14, 0, 0),
#   None,
#   None,
#   '$17.77',
#   Decimal('26.66'),
#   Decimal('213.20')),
#  (904686,
#   'IMPORTED GRAPE BRANDIES',
#   'Kehlibar Brandy',
#   321,
#   'Usb Corporation',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 2, 11, 0, 0),
#   None,
#   None,
#   '$13.62',
#   Decimal('20.43'),
#   Decimal('81.70')),
#  (904687,
#   'AMERICAN GRAPE BRANDIES',
#   'Christian Brothers Frost White',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   1000,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 3, 4, 0, 0),
#   None,
#   '10086000000000',
#   '$7.11',
#   Decimal('10.67'),
#   Decimal('85.28')),
#  (904688,
#   'SINGLE MALT SCOTCH',
#   'Glenrothes Select Reserve',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 5, 0, 0),
#   None,
#   '10721100000000',
#   '$30.72',
#   Decimal('46.08'),
#   Decimal('184.30')),
#  (904689,
#   'IMPORTED VODKA',
#   'Ciroc Red Berry',
#   260,
#   'Diageo Americas',
#   375,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 3, 9, 0, 0),
#   None,
#   '10088100000000',
#   '$8.27',
#   Decimal('12.41'),
#   Decimal('99.21')),
#  (904690,
#   'SCOTCH WHISKIES',
#   "Lauder's Scotch Mini",
#   55,
#   'Sazerac North America',
#   50,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 10, 0, 0),
#   None,
#   '10080700000000',
#   '$4.55',
#   Decimal('6.83'),
#   Decimal('54.55')),
#  (904691,
#   'SINGLE MALT SCOTCH',
#   'Dt 1990 Royal Lochnagar 18yo',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '108',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   None,
#   '$83.00',
#   Decimal('124.50'),
#   Decimal('83.00')),
#  (904692,
#   'IMPORTED VODKA',
#   'Ciroc Coconut',
#   260,
#   'Diageo Americas',
#   375,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 3, 9, 0, 0),
#   None,
#   '10088100000000',
#   '$9.25',
#   Decimal('13.88'),
#   Decimal('110.91')),
#  (904693,
#   'SCOTCH WHISKIES',
#   'Bruichladdich Carnoustie Links 14yr',
#   501,
#   'Winebow Inc.',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2009, 4, 29, 0, 0),
#   None,
#   None,
#   '$44.28',
#   Decimal('66.42'),
#   Decimal('265.70')),
#  (904694,
#   'SINGLE MALT SCOTCH',
#   'Dt 1990 Dalmore 18yr Cask',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '113',
#   datetime.datetime(2010, 3, 16, 0, 0),
#   None,
#   None,
#   '$65.00',
#   Decimal('97.50'),
#   Decimal('65.00')),
#  (904695,
#   'SINGLE MALT SCOTCH',
#   'Benriach Single Malt 20yr',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 3, 16, 0, 0),
#   None,
#   None,
#   '$70.27',
#   Decimal('105.41'),
#   Decimal('70.27')),
#  (904696,
#   'IMPORTED VODKA',
#   'Pearl Plum Vodka',
#   434,
#   'Luxco-st Louis',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 3, 5, 0, 0),
#   None,
#   '10088400000000',
#   '$7.85',
#   Decimal('11.78'),
#   Decimal('94.25')),
#  (904697,
#   'DISTILLED SPIRITS SPECIALTY',
#   'Rumchata',
#   305,
#   'Mhw Ltd',
#   750,
#   6,
#   1,
#   None,
#   '27',
#   datetime.datetime(2010, 3, 18, 0, 0),
#   None,
#   None,
#   '$10.83',
#   Decimal('16.25'),
#   Decimal('65.00')),
#  (904698,
#   'STRAIGHT BOURBON WHISKIES',
#   'Black Maple Hill Small Batch DNO',
#   108,
#   'Cvi Brands',
#   750,
#   12,
#   1,
#   None,
#   '95',
#   datetime.datetime(2010, 3, 18, 0, 0),
#   None,
#   None,
#   '$28.06',
#   Decimal('42.09'),
#   Decimal('336.70')),
#  (904699,
#   'FLAVORED VODKA',
#   'Uv Blue Raspberry Vodka Glass',
#   380,
#   'Phillips Beverage Company',
#   375,
#   12,
#   1,
#   None,
#   '60',
#   datetime.datetime(2009, 5, 1, 0, 0),
#   None,
#   None,
#   '$2.82',
#   Decimal('4.23'),
#   Decimal('33.78')),
#  (904700,
#   'SCOTCH WHISKIES',
#   'Peat Monster Whiskey',
#   305,
#   'Mhw Ltd',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2009, 4, 14, 0, 0),
#   None,
#   None,
#   '$27.50',
#   Decimal('41.25'),
#   Decimal('165.00')),
#  (904701,
#   'BLENDED WHISKIES',
#   'Seagrams Seven Crown Dark Honey Mini',
#   260,
#   'Diageo Americas',
#   502,
#   12,
#   1,
#   None,
#   '71',
#   datetime.datetime(2010, 3, 2, 0, 0),
#   None,
#   None,
#   '$8.09',
#   Decimal('12.14'),
#   Decimal('97.03')),
#  (904702,
#   'JAMAICA RUM',
#   "Myers's Legend Rum",
#   260,
#   'Diageo Americas',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 16, 0, 0),
#   None,
#   None,
#   '$11.99',
#   Decimal('17.99'),
#   Decimal('71.94')),
#  (904703,
#   'TEQUILA',
#   'Jose Cuervo Especial Silver',
#   395,
#   'Proximo',
#   375,
#   24,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 18, 0, 0),
#   None,
#   None,
#   '$5.49',
#   Decimal('8.24'),
#   Decimal('131.85')),
#  (904704,
#   'AMERICAN DRY GINS',
#   'New Amsterdam Mini',
#   205,
#   'E And J Gallo Winery',
#   502,
#   12,
#   10,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 19, 0, 0),
#   None,
#   '10085000000000',
#   '$4.87',
#   Decimal('7.31'),
#   Decimal('58.44')),
#  (904705,
#   'SCOTCH WHISKIES',
#   'Johnnie Walker Black 100th Anniversary',
#   260,
#   'Diageo Americas',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 24, 0, 0),
#   None,
#   None,
#   '$21.96',
#   Decimal('32.94'),
#   Decimal('131.75')),
#  (904706,
#   'MISCELLANEOUS SCHNAPPS',
#   'Ice Hole Cherry Schnapps',
#   380,
#   'Phillips Beverage Company',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 24, 0, 0),
#   '87116035423',
#   '10087100000000',
#   '$5.15',
#   Decimal('7.73'),
#   Decimal('61.80')),
#  (904707,
#   'APPLE SCHNAPPS',
#   'Hiram Walker Sour Apple Schnapps',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1000,
#   12,
#   1,
#   None,
#   '30',
#   datetime.datetime(2010, 3, 25, 0, 0),
#   None,
#   None,
#   '$4.50',
#   Decimal('6.75'),
#   Decimal('53.94')),
#  (904708,
#   'AMERICAN COCKTAILS',
#   "Tgi Friday's Blender Strawberry Daiquiri",
#   260,
#   'Diageo Americas',
#   1750,
#   6,
#   1,
#   None,
#   '25',
#   datetime.datetime(2010, 3, 30, 0, 0),
#   '82000157663',
#   '82000744399',
#   '$7.94',
#   Decimal('11.91'),
#   Decimal('47.64')),
#  (904709,
#   'FLAVORED VODKA',
#   'Three Olives Cherry',
#   395,
#   'Proximo',
#   375,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 3, 31, 0, 0),
#   None,
#   '10089700000000',
#   '$5.40',
#   Decimal('8.10'),
#   Decimal('64.79')),
#  (904710,
#   'AMERICAN DRY GINS',
#   'New Amsterdam Gin',
#   205,
#   'E And J Gallo Winery',
#   100,
#   48,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 25, 0, 0),
#   '85000008898',
#   '10085000000000',
#   '$1.00',
#   Decimal('1.50'),
#   Decimal('48.00')),
#  (904711,
#   'FLAVORED VODKA',
#   'Smirnoff Twist Of Black Cherry Mini',
#   260,
#   'Diageo Americas',
#   502,
#   12,
#   10,
#   None,
#   '70',
#   datetime.datetime(2009, 9, 3, 0, 0),
#   '82000001409',
#   '82000768197',
#   '$5.72',
#   Decimal('8.58'),
#   Decimal('68.58')),
#  (904712,
#   'FLAVORED VODKA',
#   'Three Olives Grape',
#   395,
#   'Proximo',
#   375,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 3, 31, 0, 0),
#   None,
#   '10089700000000',
#   '$5.40',
#   Decimal('8.10'),
#   Decimal('64.79')),
#  (904713,
#   'TEQUILA',
#   'Cabrito Reposado',
#   256,
#   'Haas Brothers',
#   375,
#   24,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 5, 14, 0, 0),
#   None,
#   None,
#   '$7.74',
#   Decimal('11.61'),
#   Decimal('185.70')),
#  (904714,
#   'TEQUILA',
#   'El Jimador Reposado Tequila',
#   85,
#   'Brown-forman Corporation',
#   375,
#   24,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 4, 22, 0, 0),
#   None,
#   '10744600000000',
#   '$5.86',
#   Decimal('8.79'),
#   Decimal('140.67')),
#  (904715,
#   'IMPORTED VODKA',
#   'Zubrowka Bison Grass Vodka DNO',
#   310,
#   'Marsalle Company/stoller Warehouse',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 1, 20, 0, 0),
#   None,
#   None,
#   '$15.26',
#   Decimal('22.89'),
#   Decimal('183.15')),
#  (904716,
#   'SINGLE MALT SCOTCH',
#   'Springbank 12y Cream Sherry Cask',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '112',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   None,
#   '$66.00',
#   Decimal('99.00'),
#   Decimal('66.00')),
#  (904717,
#   'IMPORTED VODKA',
#   'Finlandia Wild Berries Vodka',
#   85,
#   'Brown-forman Corporation',
#   750,
#   12,
#   1,
#   None,
#   '75',
#   datetime.datetime(2009, 4, 21, 0, 0),
#   None,
#   '10081100000000',
#   '$10.55',
#   Decimal('15.83'),
#   Decimal('126.58')),
#  (904718,
#   'IRISH WHISKIES',
#   "Finian's Irish Whiskey",
#   287,
#   'Chatham Importsinc',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 2, 22, 0, 0),
#   None,
#   '40039400000000',
#   '$17.78',
#   Decimal('26.67'),
#   Decimal('106.70')),
#  (904719,
#   'RASPBERRY SCHNAPPS',
#   'Hiram Walker Raspberry Schnapps',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1000,
#   12,
#   1,
#   None,
#   '30',
#   datetime.datetime(2010, 3, 25, 0, 0),
#   None,
#   '89540472973',
#   '$4.50',
#   Decimal('6.75'),
#   Decimal('53.94')),
#  (904720,
#   '80 PROOF VODKA',
#   'Fuzzy Vodka',
#   305,
#   'Mhw Ltd',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 5, 15, 0, 0),
#   None,
#   None,
#   '$15.00',
#   Decimal('22.50'),
#   Decimal('90.00')),
#  (904721,
#   'TEQUILA',
#   'El Jimador Reposado Tequila Mini',
#   85,
#   'Brown-forman Corporation',
#   50,
#   10,
#   12,
#   None,
#   '80',
#   datetime.datetime(2009, 4, 22, 0, 0),
#   '744607000000',
#   '40744600000000',
#   '$9.87',
#   Decimal('14.81'),
#   Decimal('98.66')),
#  (904722,
#   'FLAVORED RUM',
#   'Cabana Bay Vanilla Spice',
#   298,
#   'White Rock Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '48',
#   datetime.datetime(2009, 7, 2, 0, 0),
#   '81932242126',
#   None,
#   '$6.08',
#   Decimal('9.12'),
#   Decimal('72.94')),
#  (904723,
#   'SINGLE MALT SCOTCH',
#   'Glendronach 18yo',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '92',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   '87229170301',
#   '$73.25',
#   Decimal('109.88'),
#   Decimal('73.25')),
#  (904724,
#   'SINGLE BARREL BOURBON WHISKIES',
#   "Michter's Single Barrel 10yo Bourbon",
#   287,
#   'Chatham Importsinc',
#   750,
#   3,
#   1,
#   None,
#   '94',
#   datetime.datetime(2010, 2, 22, 0, 0),
#   None,
#   None,
#   '$45.23',
#   Decimal('67.85'),
#   Decimal('135.70')),
#  (904725,
#   'IMPORTED VODKA',
#   'Skyy 90',
#   461,
#   'Campari(skyy)',
#   750,
#   6,
#   1,
#   None,
#   '90',
#   datetime.datetime(2010, 4, 1, 0, 0),
#   None,
#   None,
#   '$16.67',
#   Decimal('25.01'),
#   Decimal('100.00')),
#  (904726,
#   'FLAVORED VODKA',
#   'Uv Pink Lemonade Vodka Glass',
#   380,
#   'Phillips Beverage Company',
#   375,
#   12,
#   1,
#   None,
#   '60',
#   datetime.datetime(2009, 5, 1, 0, 0),
#   '87116014985',
#   '10087100000000',
#   '$3.44',
#   Decimal('5.16'),
#   Decimal('41.30')),
#  (904727,
#   'FLAVORED VODKA',
#   'Smirnoff Twist Of Green Apple',
#   260,
#   'Diageo Americas',
#   1000,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 6, 0, 0),
#   None,
#   None,
#   '$9.20',
#   Decimal('13.80'),
#   Decimal('110.43')),
#  (904728,
#   'BLENDED WHISKIES',
#   'Mccormick Blended Whiskey',
#   300,
#   'Mccormick Distilling Company',
#   375,
#   24,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 4, 8, 0, 0),
#   None,
#   '10085600000000',
#   '$1.90',
#   Decimal('2.85'),
#   Decimal('45.52')),
#  (904729,
#   'FLAVORED VODKA',
#   'Smirnoff Dark Roasted Espresso',
#   260,
#   'Diageo Americas',
#   750,
#   12,
#   1,
#   None,
#   '100',
#   datetime.datetime(2010, 4, 8, 0, 0),
#   None,
#   None,
#   '$8.11',
#   Decimal('12.17'),
#   Decimal('97.27')),
#  (904730,
#   'MISC. IMPORTED CORDIALS & LIQUEURS',
#   'Xante',
#   330,
#   'Monsieur Henri Wines Ltd.',
#   750,
#   12,
#   1,
#   None,
#   '76',
#   datetime.datetime(2010, 4, 12, 0, 0),
#   None,
#   None,
#   '$19.97',
#   Decimal('29.96'),
#   Decimal('239.64')),
#  (904731,
#   'SCOTCH WHISKIES',
#   'Chivas Royal Salute',
#   430,
#   'Seagram Americas',
#   50,
#   60,
#   1,
#   None,
#   '86',
#   datetime.datetime(1985, 11, 1, 0, 0),
#   None,
#   None,
#   '$3.70',
#   Decimal('5.55'),
#   Decimal('222.08')),
#  (904732,
#   'STRAIGHT BOURBON WHISKIES',
#   "Michter's Us*1 Small Batch Bourbon",
#   287,
#   'Chatham Importsinc',
#   750,
#   6,
#   1,
#   None,
#   '91',
#   datetime.datetime(2010, 2, 22, 0, 0),
#   None,
#   None,
#   '$23.45',
#   Decimal('35.18'),
#   Decimal('140.70')),
#  (904733,
#   '80 PROOF VODKA',
#   "Seagram's Extra Smooth Vodka",
#   255,
#   'Wilson Daniels Ltd.',
#   200,
#   24,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 2, 24, 0, 0),
#   None,
#   None,
#   '$1.76',
#   Decimal('2.64'),
#   Decimal('42.21')),
#  (904734,
#   'FLAVORED GIN',
#   "Seagram's Apple Twisted Gin",
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   375,
#   24,
#   1,
#   None,
#   '70',
#   datetime.datetime(2009, 8, 6, 0, 0),
#   '80432103760',
#   None,
#   '$3.18',
#   Decimal('4.77'),
#   Decimal('76.35')),
#  (904735,
#   'SCOTCH WHISKIES',
#   'Bruichladdich Rocks',
#   501,
#   'Winebow Inc.',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2009, 4, 29, 0, 0),
#   None,
#   None,
#   '$28.28',
#   Decimal('42.42'),
#   Decimal('169.70')),
#  (904736,
#   'BLENDED WHISKIES',
#   'Mccormick Blended Whiskey',
#   300,
#   'Mccormick Distilling Company',
#   200,
#   24,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 4, 8, 0, 0),
#   None,
#   '10085600000000',
#   '$2.26',
#   Decimal('3.39'),
#   Decimal('54.24')),
#  (904737,
#   'SINGLE MALT SCOTCH',
#   'Edradour Unchillfiltered 10yr',
#   477,
#   'Total Beverage Solutions',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 4, 12, 0, 0),
#   None,
#   None,
#   '$36.78',
#   Decimal('55.17'),
#   Decimal('220.70')),
#  (904738,
#   'SINGLE MALT SCOTCH',
#   'Edradour Caledonia 12yr',
#   477,
#   'Total Beverage Solutions',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 4, 12, 0, 0),
#   None,
#   None,
#   '$38.45',
#   Decimal('57.68'),
#   Decimal('230.70')),
#  (904739,
#   'CANADIAN WHISKIES',
#   'Lord Calvert Canadian Whisky',
#   434,
#   'Luxco-st Louis',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 4, 14, 0, 0),
#   None,
#   None,
#   '$5.25',
#   Decimal('7.87'),
#   Decimal('62.96')),
#  (904740,
#   'FLAVORED RUM',
#   'Malibu Tropical Banana',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   200,
#   48,
#   1,
#   None,
#   '42',
#   datetime.datetime(2010, 4, 14, 0, 0),
#   None,
#   None,
#   '$1.90',
#   Decimal('2.85'),
#   Decimal('91.20')),
#  (904741,
#   'FLAVORED VODKA',
#   'Smirnoff Twist Of Bluberry',
#   260,
#   'Diageo Americas',
#   375,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 19, 0, 0),
#   '82000001515',
#   '82000768791',
#   '$4.75',
#   Decimal('7.13'),
#   Decimal('56.99')),
#  (904742,
#   'FLAVORED VODKA',
#   'Smirnoff Twist Of Citrus',
#   260,
#   'Diageo Americas',
#   375,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 19, 0, 0),
#   '82000003939',
#   '82000768159',
#   '$4.50',
#   Decimal('6.75'),
#   Decimal('53.95')),
#  (904743,
#   '80 PROOF VODKA',
#   'Platinum 7x Vodka',
#   421,
#   'Sazerac Co. Inc.',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 4, 21, 0, 0),
#   None,
#   '10088000000000',
#   '$9.43',
#   Decimal('14.15'),
#   Decimal('56.60')),
#  (904744,
#   'FLAVORED RUM',
#   'Malibu Tropical Banana',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   375,
#   24,
#   1,
#   None,
#   '42',
#   datetime.datetime(2010, 4, 14, 0, 0),
#   None,
#   None,
#   '$3.89',
#   Decimal('5.84'),
#   Decimal('93.28')),
#  (904745,
#   'FLAVORED VODKA',
#   'Smirnoff Twist Of Green Apple',
#   260,
#   'Diageo Americas',
#   375,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 19, 0, 0),
#   '82000001102',
#   '82000748595',
#   '$4.50',
#   Decimal('6.75'),
#   Decimal('53.95')),
#  (904746,
#   'IRISH WHISKIES',
#   'Tullamore Dew 10 Year',
#   240,
#   'William Grant And Sons Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 2, 18, 0, 0),
#   None,
#   '10721100000000',
#   '$20.75',
#   Decimal('31.13'),
#   Decimal('124.50')),
#  (904747,
#   'PEACH SCHNAPPS',
#   '99 Peaches',
#   55,
#   'Sazerac North America',
#   750,
#   12,
#   1,
#   None,
#   '99',
#   datetime.datetime(2010, 4, 22, 0, 0),
#   None,
#   None,
#   '$9.35',
#   Decimal('14.03'),
#   Decimal('112.24')),
#  (904748,
#   'TEQUILA',
#   'Centinela Reposado',
#   256,
#   'Haas Brothers',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 5, 14, 0, 0),
#   None,
#   '10749800000000',
#   '$20.06',
#   Decimal('30.09'),
#   Decimal('240.70')),
#  (904749,
#   'BLENDED WHISKIES',
#   "Michter's Us*1 American Whiskey",
#   287,
#   'Chatham Importsinc',
#   750,
#   6,
#   1,
#   None,
#   '83',
#   datetime.datetime(2010, 2, 22, 0, 0),
#   '39383005951',
#   None,
#   '$23.45',
#   Decimal('35.18'),
#   Decimal('140.70')),
#  (904750,
#   'IMPORTED VODKA',
#   'Boomerang Vodka',
#   186,
#   'Foley Family Wines Inc.',
#   1000,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 3, 19, 0, 0),
#   None,
#   '10090400000000',
#   '$6.93',
#   Decimal('10.40'),
#   Decimal('83.11')),
#  (904751,
#   'STRAIGHT RYE WHISKIES',
#   "Michter's Us*1 Sb Rye",
#   287,
#   'Chatham Importsinc',
#   750,
#   6,
#   1,
#   None,
#   '85',
#   datetime.datetime(2010, 2, 22, 0, 0),
#   None,
#   None,
#   '$23.45',
#   Decimal('35.18'),
#   Decimal('140.70')),
#  (904752,
#   'MISCELLANEOUS SCHNAPPS',
#   '99 Black Cherries',
#   55,
#   'Sazerac North America',
#   750,
#   12,
#   1,
#   None,
#   '99',
#   datetime.datetime(2010, 4, 22, 0, 0),
#   None,
#   None,
#   '$9.35',
#   Decimal('14.03'),
#   Decimal('112.24')),
#  (904753,
#   'FLAVORED VODKA',
#   "Burnett's Pomegranate",
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 27, 0, 0),
#   None,
#   '904753',
#   '$4.83',
#   Decimal('7.25'),
#   Decimal('58.00')),
#  (904754,
#   'TEQUILA',
#   'El Mayor Extra Anejo 100% Agave HA',
#   434,
#   'Luxco-st Louis',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 4, 22, 0, 0),
#   '88352125176',
#   '10088400000000',
#   '$61.88',
#   Decimal('92.82'),
#   Decimal('371.26')),
#  (904755,
#   'SINGLE MALT SCOTCH',
#   'Glendronach 12yo',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '86',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   '87229170202',
#   '904755',
#   '$42.00',
#   Decimal('63.00'),
#   Decimal('42.00')),
#  (904756,
#   'MISC. IMPORTED CORDIALS & LIQUEURS',
#   'Faretti Biscotti',
#   287,
#   'Chatham Importsinc',
#   750,
#   6,
#   1,
#   None,
#   '56',
#   datetime.datetime(2009, 2, 23, 0, 0),
#   None,
#   '40039400000000',
#   '$20.17',
#   Decimal('30.26'),
#   Decimal('121.00')),
#  (904757,
#   'IRISH WHISKIES',
#   'Danny Boy Irish Whiskey',
#   477,
#   'Total Beverage Solutions',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 4, 23, 0, 0),
#   None,
#   None,
#   '$13.83',
#   Decimal('20.75'),
#   Decimal('166.00')),
#  (904758,
#   'CANADIAN WHISKIES',
#   'Campbell & Cooper Canadian Whiskey',
#   198,
#   'Frank-lin Distillers Products Ltd.',
#   750,
#   12,
#   1,
#   None,
#   '86',
#   datetime.datetime(2010, 4, 28, 0, 0),
#   None,
#   None,
#   '$9.48',
#   Decimal('14.22'),
#   Decimal('113.70')),
#  (904759,
#   'FLAVORED VODKA',
#   "Burnett's Strawberry",
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 28, 0, 0),
#   None,
#   '10096700000000',
#   '$4.83',
#   Decimal('7.25'),
#   Decimal('58.00')),
#  (904760,
#   'FLAVORED VODKA',
#   "Burnett's Sour Apple",
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 27, 0, 0),
#   None,
#   '10096700000000',
#   '$4.83',
#   Decimal('7.25'),
#   Decimal('58.00')),
#  (904761,
#   'FLAVORED VODKA',
#   "Burnett's Mango",
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 28, 0, 0),
#   None,
#   '10096700000000',
#   '$4.83',
#   Decimal('7.25'),
#   Decimal('58.00')),
#  (904762,
#   'CANADIAN WHISKIES',
#   'Canadian Regency Light',
#   350,
#   'Luxco-cleveland',
#   1750,
#   6,
#   1,
#   None,
#   '60',
#   datetime.datetime(2010, 4, 28, 0, 0),
#   '86816642023',
#   '10086800000000',
#   '$7.78',
#   Decimal('11.67'),
#   Decimal('46.65')),
#  (904763,
#   'TEQUILA',
#   'Don Julio Reposado',
#   260,
#   'Diageo Americas',
#   375,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 8, 11, 0, 0),
#   None,
#   '10674500000000',
#   '$13.99',
#   Decimal('20.99'),
#   Decimal('167.93')),
#  (904764,
#   'FLAVORED VODKA',
#   'Firefly Lemon Tea Vodka',
#   421,
#   'Sazerac Co. Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 29, 0, 0),
#   None,
#   '10897300000000',
#   '$10.00',
#   Decimal('15.00'),
#   Decimal('119.96')),
#  (904765,
#   'IMPORTED VODKA',
#   'Alchemia Chocolate Vodka',
#   305,
#   'Mhw Ltd',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 4, 30, 0, 0),
#   None,
#   '10894500000000',
#   '$13.00',
#   Decimal('19.50'),
#   Decimal('78.00')),
#  (904766,
#   'IMPORTED VODKA',
#   'X Rated Vodka(dno)',
#   461,
#   'Campari(skyy)',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 5, 1, 0, 0),
#   None,
#   None,
#   '$17.14',
#   Decimal('25.71'),
#   Decimal('102.82')),
#  (904767,
#   'SINGLE MALT SCOTCH',
#   'Springbank 18yr',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 4, 30, 0, 0),
#   None,
#   None,
#   '$86.50',
#   Decimal('129.75'),
#   Decimal('519.00')),
#  (904768,
#   'MISCELLANEOUS SCHNAPPS',
#   'Ice Hole Plum Schnapps',
#   380,
#   'Phillips Beverage Company',
#   1000,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 5, 6, 0, 0),
#   None,
#   '904768',
#   '$6.75',
#   Decimal('10.13'),
#   Decimal('81.00')),
#  (904769,
#   'FLAVORED VODKA',
#   "Burnett's Sweet Tea Vodka",
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '60',
#   datetime.datetime(2010, 5, 6, 0, 0),
#   None,
#   '10096700000000',
#   '$4.83',
#   Decimal('7.25'),
#   Decimal('58.00')),
#  (904770,
#   'FLAVORED VODKA',
#   "Burnett's Fruit Punch",
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 28, 0, 0),
#   None,
#   None,
#   '$4.55',
#   Decimal('6.83'),
#   Decimal('54.55')),
#  (904771,
#   'FLAVORED VODKA',
#   'Jeremiah Weed Sweet Tea Mini',
#   260,
#   'Diageo Americas',
#   502,
#   120,
#   1,
#   None,
#   '70',
#   datetime.datetime(2009, 5, 28, 0, 0),
#   None,
#   None,
#   '$0.45',
#   Decimal('0.68'),
#   Decimal('54.34')),
#  (904772,
#   'IMPORTED VODKA',
#   'Belvedere Black Raspberry',
#   420,
#   'Moet Hennessy Usa Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 5, 7, 0, 0),
#   None,
#   '10081800000000',
#   '$17.15',
#   Decimal('25.73'),
#   Decimal('102.90')),
#  (904773,
#   'IMPORTED VODKA',
#   'Vikingfjord Vodka',
#   761,
#   'Capstone International Inc',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 5, 12, 0, 0),
#   None,
#   None,
#   '$13.25',
#   Decimal('19.88'),
#   Decimal('79.50')),
#  (904774,
#   'FLAVORED VODKA',
#   'James River Plantation Sweet Tea',
#   305,
#   'Mhw Ltd',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 5, 28, 0, 0),
#   None,
#   '10890400000000',
#   '$9.92',
#   Decimal('14.88'),
#   Decimal('119.00')),
#  (904775,
#   'FLAVORED VODKA',
#   'Paramount Cherry Vodka',
#   350,
#   'Luxco-cleveland',
#   750,
#   12,
#   1,
#   None,
#   '65',
#   datetime.datetime(2009, 5, 15, 0, 0),
#   None,
#   None,
#   '$4.83',
#   Decimal('7.25'),
#   Decimal('58.00')),
#  (904776,
#   'IMPORTED VODKA',
#   'Kai Vodka',
#   305,
#   'Mhw Ltd',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 5, 14, 0, 0),
#   None,
#   None,
#   '$17.17',
#   Decimal('25.76'),
#   Decimal('103.00')),
#  (904777,
#   'FLAVORED RUM',
#   'Cruzan Guava Rum',
#   65,
#   'Jim Beam Brands',
#   750,
#   12,
#   1,
#   None,
#   '55',
#   datetime.datetime(2010, 6, 1, 0, 0),
#   None,
#   '10080700000000',
#   '$6.83',
#   Decimal('10.25'),
#   Decimal('81.96')),
#  (904778,
#   'IMPORTED VODKA',
#   'Crystal Head Vodka',
#   255,
#   'Wilson Daniels Ltd.',
#   1750,
#   3,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 5, 20, 0, 0),
#   None,
#   '904778',
#   '$51.99',
#   Decimal('77.99'),
#   Decimal('155.98')),
#  (904779,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Bols Strawberry Liqueur',
#   305,
#   'Mhw Ltd',
#   1000,
#   12,
#   1,
#   None,
#   '440',
#   datetime.datetime(2010, 6, 1, 0, 0),
#   None,
#   '10080900000000',
#   '$5.86',
#   Decimal('8.79'),
#   Decimal('70.34')),
#  (904780,
#   'IMPORTED VODKA',
#   'Three Olives Watermelon Vodka',
#   395,
#   'Proximo',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 6, 4, 0, 0),
#   None,
#   '10089700000000',
#   '$9.96',
#   Decimal('14.94'),
#   Decimal('119.49')),
#  (904781,
#   'MISCELLANEOUS SCHNAPPS',
#   'Mothers Schnapps Cherry',
#   322,
#   'U.s. Distilled Prod. Co',
#   750,
#   12,
#   1,
#   None,
#   '30',
#   datetime.datetime(2010, 6, 11, 0, 0),
#   '84279979014',
#   '10084300000000',
#   '$4.50',
#   Decimal('6.75'),
#   Decimal('53.94')),
#  (904782,
#   '80 PROOF VODKA',
#   'Uv Vodka Pet',
#   380,
#   'Phillips Beverage Company',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 6, 14, 0, 0),
#   None,
#   None,
#   '$10.58',
#   Decimal('15.87'),
#   Decimal('63.50')),
#  (904783,
#   'IMPORTED VODKA',
#   'Vesica Vodka',
#   14,
#   "Adamba Imports Int'l Inc.",
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 6, 14, 0, 0),
#   None,
#   '10076800000000',
#   '$5.99',
#   Decimal('8.99'),
#   Decimal('71.88')),
#  (904784,
#   'SINGLE MALT SCOTCH',
#   'Glenlivet Cellar Collection 1973',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   750,
#   1,
#   1,
#   None,
#   '98',
#   datetime.datetime(2010, 6, 16, 0, 0),
#   None,
#   None,
#   '$625.00',
#   Decimal('937.50'),
#   Decimal('625.00')),
#  (904785,
#   'MISCELLANEOUS SCHNAPPS',
#   'Mothers Schnapps Peppermint',
#   322,
#   'U.s. Distilled Prod. Co',
#   750,
#   12,
#   1,
#   None,
#   '60',
#   datetime.datetime(2010, 6, 11, 0, 0),
#   None,
#   '10084300000000',
#   '$4.50',
#   Decimal('6.75'),
#   Decimal('53.94')),
#  (904786,
#   'SINGLE MALT SCOTCH',
#   'Dt Glendronach 33yr Three Generations',
#   391,
#   'Anchor Distilling (preiss Imports)',
#   750,
#   1,
#   1,
#   None,
#   '102',
#   datetime.datetime(2009, 12, 9, 0, 0),
#   None,
#   None,
#   '$160.50',
#   Decimal('240.75'),
#   Decimal('160.50')),
#  (904787,
#   'CREAM LIQUEURS',
#   'E & J Caramel Temptation',
#   205,
#   'E And J Gallo Winery',
#   750,
#   12,
#   1,
#   None,
#   '34',
#   datetime.datetime(2010, 6, 21, 0, 0),
#   None,
#   None,
#   '$5.99',
#   Decimal('8.99'),
#   Decimal('71.92')),
#  (904788,
#   '80 PROOF VODKA',
#   'Charbay Clear Vodka',
#   155,
#   'Domaine Charbay',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 6, 10, 0, 0),
#   None,
#   None,
#   '$21.50',
#   Decimal('32.25'),
#   Decimal('129.00')),
#  (904789,
#   'SCOTCH WHISKIES',
#   'Bruichladdich Torrey Pines 15yr',
#   501,
#   'Winebow Inc.',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2009, 4, 29, 0, 0),
#   None,
#   None,
#   '$48.28',
#   Decimal('72.42'),
#   Decimal('289.70')),
#  (904790,
#   'SCOTCH WHISKIES',
#   'Macallan 12yr Scotch Mini',
#   305,
#   'Mhw Ltd',
#   600,
#   10,
#   12,
#   None,
#   '86',
#   datetime.datetime(2010, 6, 25, 0, 0),
#   None,
#   '904790',
#   '$36.26',
#   Decimal('54.39'),
#   Decimal('362.53')),
#  (904791,
#   'IMPORTED GRAPE BRANDIES',
#   'Courvoisier Xo',
#   65,
#   'Jim Beam Brands',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 6, 0, 0),
#   '80686965022',
#   '10080700000000',
#   '$83.99',
#   Decimal('125.99'),
#   Decimal('503.96')),
#  (904792,
#   'TEQUILA',
#   'Sauza Tres Generaciones Anejo DNO',
#   65,
#   'Jim Beam Brands',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 6, 0, 0),
#   None,
#   None,
#   '$23.62',
#   Decimal('35.43'),
#   Decimal('141.72')),
#  (904793,
#   'AMERICAN COCKTAILS',
#   'Tooters Red Diculous On The Beach',
#   308,
#   'Mango Bottling Inc.',
#   375,
#   12,
#   1,
#   None,
#   '30',
#   datetime.datetime(2009, 4, 28, 0, 0),
#   None,
#   None,
#   '$4.94',
#   Decimal('7.41'),
#   Decimal('59.25')),
#  (904794,
#   'SINGLE MALT SCOTCH',
#   'Laphroaig Quarter Cask',
#   65,
#   'Jim Beam Brands',
#   750,
#   6,
#   1,
#   None,
#   '96',
#   datetime.datetime(2010, 7, 6, 0, 0),
#   None,
#   '904794',
#   '$29.39',
#   Decimal('44.09'),
#   Decimal('176.36')),
#  (904795,
#   'SCOTCH WHISKIES',
#   'Dimple Pinch(haig & Haig)',
#   260,
#   'Diageo Americas',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 6, 0, 0),
#   None,
#   '904795',
#   '$21.24',
#   Decimal('31.86'),
#   Decimal('254.90')),
#  (904796,
#   'SCOTCH WHISKIES',
#   'Johnnie Walker Gold DNO',
#   260,
#   'Diageo Americas',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 6, 9, 0, 0),
#   None,
#   None,
#   '$49.85',
#   Decimal('74.78'),
#   Decimal('598.15')),
#  (904797,
#   'SCOTCH WHISKIES',
#   'Ardbeg Airigh Nam Beist',
#   420,
#   'Moet Hennessy Usa Inc.',
#   750,
#   6,
#   1,
#   None,
#   '92',
#   datetime.datetime(2010, 7, 6, 0, 0),
#   None,
#   None,
#   '$42.58',
#   Decimal('63.87'),
#   Decimal('255.48')),
#  (904798,
#   'CANADIAN WHISKIES',
#   'Paramount Canadian Whiskey',
#   350,
#   'Luxco-cleveland',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 4, 27, 0, 0),
#   None,
#   None,
#   '$8.88',
#   Decimal('13.32'),
#   Decimal('53.26')),
#  (904799,
#   'FLAVORED VODKA',
#   "Burnett's Watermelon",
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 4, 27, 0, 0),
#   None,
#   '10096700000000',
#   '$4.83',
#   Decimal('7.25'),
#   Decimal('58.00')),
#  (904800,
#   'PUERTO RICO & VIRGIN ISLANDS RUM',
#   'Pyrat Xo Reserve',
#   410,
#   'The Patron Spirits Company',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 8, 0, 0),
#   '721734000000',
#   '10721700000000',
#   '$13.08',
#   Decimal('19.62'),
#   Decimal('78.50')),
#  (904801,
#   'IMPORTED VODKA',
#   'Pinnacle Banana(dno)',
#   298,
#   'White Rock Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2010, 7, 12, 0, 0),
#   None,
#   '10089700000000',
#   '$7.38',
#   Decimal('11.07'),
#   Decimal('88.55')),
#  (904802,
#   'TEQUILA',
#   'Lunazul Tequila Reposado',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 12, 0, 0),
#   None,
#   '904802',
#   '$10.63',
#   Decimal('15.95'),
#   Decimal('127.60')),
#  (904803,
#   'MISC. AMERICAN CORDIALS & LIQUEURS',
#   'Veev Acai',
#   489,
#   'Veev Spirits Llc',
#   750,
#   6,
#   1,
#   None,
#   '60',
#   datetime.datetime(2010, 7, 14, 0, 0),
#   '904803',
#   '904803',
#   '$14.00',
#   Decimal('21.00'),
#   Decimal('84.00')),
#  (904804,
#   'TEQUILA',
#   'Milagro Tequila Silver',
#   240,
#   'William Grant And Sons Inc.',
#   375,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2009, 6, 12, 0, 0),
#   None,
#   None,
#   '$7.97',
#   Decimal('11.96'),
#   Decimal('95.60')),
#  (904805,
#   'STRAIGHT BOURBON WHISKIES',
#   'Heaven Hill Old Style Green 6yr',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '90',
#   datetime.datetime(2010, 7, 15, 0, 0),
#   None,
#   '10096700000000',
#   '$5.45',
#   Decimal('8.18'),
#   Decimal('65.35')),
#  (904806,
#   'PUERTO RICO & VIRGIN ISLANDS RUM',
#   'Zaya Rum',
#   255,
#   'Wilson Daniels Ltd.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 12, 0, 0),
#   '720816000000',
#   '20720800000000',
#   '$16.66',
#   Decimal('24.99'),
#   Decimal('99.94')),
#  (904807,
#   'STRAIGHT BOURBON WHISKIES',
#   'Heaven Hill Old Style Green 90',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '90',
#   datetime.datetime(2010, 7, 15, 0, 0),
#   None,
#   '10096700000000',
#   '$4.61',
#   Decimal('6.92'),
#   Decimal('55.35')),
#  (904808,
#   'TEQUILA',
#   'Cazadores Reposado',
#   35,
#   'Bacardi U.s.a. Inc.',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 8, 0, 0),
#   None,
#   None,
#   '$29.37',
#   Decimal('44.06'),
#   Decimal('176.21')),
#  (904809,
#   'STRAIGHT BOURBON WHISKIES',
#   'Phillips Union Whiskey',
#   380,
#   'Phillips Beverage Company',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2010, 7, 19, 0, 0),
#   '87116080003',
#   '10087100000000',
#   '$14.30',
#   Decimal('21.45'),
#   Decimal('85.80')),
#  (904810,
#   'SINGLE MALT SCOTCH',
#   'Laphroaig 21yr',
#   65,
#   'Jim Beam Brands',
#   750,
#   6,
#   1,
#   None,
#   '106',
#   datetime.datetime(2010, 7, 12, 0, 0),
#   None,
#   None,
#   '$104.98',
#   Decimal('157.47'),
#   Decimal('629.88')),
#  (904811,
# ...
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(1983, 5, 1, 0, 0),
#   '81128010621',
#   '81128010225',
#   '$6.47',
#   Decimal('9.71'),
#   Decimal('77.64')),
#  (17827,
#   'STRAIGHT BOURBON WHISKIES',
#   'Early Times 36mo Ky Str Bourbon',
#   85,
#   'Brown-forman Corporation',
#   1000,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2000, 8, 1, 0, 0),
#   None,
#   None,
#   '$6.94',
#   Decimal('10.41'),
#   Decimal('83.25')),
#  (17828,
#   'STRAIGHT BOURBON WHISKIES',
#   'Early Times 36mo Ky Str Bourbon',
#   85,
#   'Brown-forman Corporation',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(1988, 6, 1, 0, 0),
#   None,
#   None,
#   '$9.00',
#   Decimal('13.50'),
#   Decimal('54.00')),
#  (17830,
#   'STRAIGHT BOURBON WHISKIES',
#   'Early Times 36 Mo Ky Str Bourbon Pet',
#   85,
#   'Brown-forman Corporation',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2004, 2, 1, 0, 0),
#   '81128010508',
#   '81128010416',
#   '$12.31',
#   Decimal('18.47'),
#   Decimal('73.81')),
#  (17836,
#   'STRAIGHT BOURBON WHISKIES',
#   'Early Times Bourbon 354',
#   85,
#   'Brown-forman Corporation',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2012, 3, 1, 0, 0),
#   None,
#   None,
#   '$9.46',
#   Decimal('14.19'),
#   Decimal('113.48')),
#  (1785,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Grey Goose Le Citron Rocks Glass Pack',
#   192,
#   'Sidney Frank Importing Co.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2002, 8, 1, 0, 0),
#   None,
#   None,
#   '$15.46',
#   Decimal('23.19'),
#   Decimal('92.75')),
#  (1788,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Vox Vodka With Shaker',
#   65,
#   'Jim Beam Brands',
#   750,
#   6,
#   1,
#   None,
#   '63',
#   datetime.datetime(2002, 6, 1, 0, 0),
#   None,
#   None,
#   '$15.99',
#   Decimal('23.99'),
#   Decimal('95.96')),
#  (1791,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Chopin Vodka With Martini Shaker',
#   305,
#   'Mhw Ltd',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$15.40',
#   Decimal('23.10'),
#   Decimal('92.39')),
#  (17916,
#   'STRAIGHT BOURBON WHISKIES',
#   'Elijah Craig',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '94',
#   datetime.datetime(2013, 1, 1, 0, 0),
#   '96749000067',
#   '10096700000000',
#   '$14.04',
#   Decimal('21.06'),
#   Decimal('168.45')),
#  (1793,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Christian Brothers Amber Cream Gift Set',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   6,
#   1,
#   None,
#   '34',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$5.86',
#   Decimal('8.79'),
#   Decimal('35.16')),
#  (17950,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Evan Williams Master Select Decanter',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   6,
#   1,
#   None,
#   '90',
#   datetime.datetime(2001, 8, 1, 0, 0),
#   None,
#   None,
#   '$10.83',
#   Decimal('16.25'),
#   Decimal('65.00')),
#  (17954,
#   'STRAIGHT BOURBON WHISKIES',
#   'Evan Williams Black Label',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   375,
#   24,
#   1,
#   None,
#   '86',
#   datetime.datetime(2012, 2, 1, 0, 0),
#   '96749021642',
#   '96749021642',
#   '$3.19',
#   Decimal('4.79'),
#   Decimal('76.50')),
#  (17956,
#   'STRAIGHT BOURBON WHISKIES',
#   'Evan Williams Str Bourbon',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '86',
#   datetime.datetime(1979, 2, 1, 0, 0),
#   '96749021345',
#   '10096700000000',
#   '$6.81',
#   Decimal('10.55'),
#   Decimal('81.68')),
#  (17957,
#   'STRAIGHT BOURBON WHISKIES',
#   'Evan Williams Bourbon',
#   350,
#   'Luxco-cleveland',
#   1000,
#   12,
#   1,
#   None,
#   '90',
#   datetime.datetime(1999, 8, 1, 0, 0),
#   None,
#   None,
#   '$6.01',
#   Decimal('9.02'),
#   Decimal('72.06')),
#  (17958,
#   'STRAIGHT BOURBON WHISKIES',
#   'Evan Williams Yr Str Bourbon',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   1750,
#   6,
#   1,
#   None,
#   '86',
#   datetime.datetime(1991, 4, 1, 0, 0),
#   '96749021147',
#   '10096700000000',
#   '$13.71',
#   Decimal('21.19'),
#   Decimal('82.25')),
#  (1799,
#   'SPICED RUM',
#   'Captain Morgan Spiced Barrel',
#   260,
#   'Diageo Americas',
#   1750,
#   6,
#   1,
#   None,
#   '70',
#   datetime.datetime(2013, 3, 1, 0, 0),
#   '82000759102',
#   '10082000000000',
#   '$18.00',
#   Decimal('27.00'),
#   Decimal('107.95')),
#  (18006,
#   'STRAIGHT BOURBON WHISKIES',
#   'Buffalo Trace Bourbon',
#   421,
#   'Sazerac Co. Inc.',
#   750,
#   12,
#   1,
#   None,
#   '90',
#   datetime.datetime(2009, 9, 1, 0, 0),
#   '80244009236',
#   '10080200000000',
#   '$12.48',
#   Decimal('18.72'),
#   Decimal('149.70')),
#  (1802,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Skyy Citrus With Cosmo Mix',
#   461,
#   'Campari(skyy)',
#   750,
#   6,
#   1,
#   None,
#   '70',
#   datetime.datetime(2004, 6, 1, 0, 0),
#   None,
#   None,
#   '$9.49',
#   Decimal('14.24'),
#   Decimal('56.92')),
#  (1804,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Absolut Tri Pack Cit/mand/blu',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   375,
#   18,
#   1,
#   None,
#   '80',
#   datetime.datetime(2002, 9, 25, 0, 0),
#   None,
#   None,
#   '$5.91',
#   Decimal('8.87'),
#   Decimal('106.32')),
#  (18046,
#   'STRAIGHT BOURBON WHISKIES',
#   'Evan Williams Green Label',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2013, 2, 1, 0, 0),
#   '96749021321',
#   '96749021321',
#   '$4.94',
#   Decimal('7.41'),
#   Decimal('59.25')),
#  (18048,
#   'STRAIGHT BOURBON WHISKIES',
#   'Evan Williams Green Label',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2013, 2, 1, 0, 0),
#   '96749021123',
#   '96749021123',
#   '$9.94',
#   Decimal('14.91'),
#   Decimal('59.60')),
#  (1808,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Bacardi Light Party Zone',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2002, 9, 1, 0, 0),
#   None,
#   None,
#   '$6.75',
#   Decimal('10.13'),
#   Decimal('80.94')),
#  (1809,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Skyy Citrus W/cosmo Mix',
#   461,
#   'Campari(skyy)',
#   1750,
#   3,
#   1,
#   None,
#   '70',
#   datetime.datetime(2002, 9, 25, 0, 0),
#   None,
#   None,
#   '$15.93',
#   Decimal('23.90'),
#   Decimal('47.79')),
#  (18096,
#   'STRAIGHT RYE WHISKIES',
#   'Evan Williams 1783',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '86',
#   datetime.datetime(2014, 3, 1, 0, 0),
#   '96749141326',
#   '10096700000000',
#   '$9.47',
#   Decimal('14.21'),
#   Decimal('113.60')),
#  (1810,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Bacardi O Glass Pack',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '70',
#   datetime.datetime(2002, 8, 1, 0, 0),
#   None,
#   None,
#   '$7.53',
#   Decimal('11.30'),
#   Decimal('45.20')),
#  (18116,
#   'STRAIGHT BOURBON WHISKIES',
#   'Evan Williams Black Label Traveler',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '86',
#   datetime.datetime(2013, 4, 1, 0, 0),
#   '96749021772',
#   '10096700000000',
#   '$6.81',
#   Decimal('10.55'),
#   Decimal('81.68')),
#  (18120,
#   'SINGLE BARREL BOURBON WHISKIES',
#   'Evan Williams Vintage',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   6,
#   1,
#   None,
#   '86',
#   datetime.datetime(1995, 2, 1, 0, 0),
#   '96749750016',
#   '10096700000000',
#   '$14.97',
#   Decimal('22.46'),
#   Decimal('89.80')),
#  (18126,
#   'SINGLE BARREL BOURBON WHISKIES',
#   'Evan Williams Millennium Sgl. Bb. Vtg. Res.',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   6,
#   1,
#   None,
#   '86',
#   datetime.datetime(1999, 9, 1, 0, 0),
#   None,
#   None,
#   '$24.53',
#   Decimal('36.80'),
#   Decimal('147.15')),
#  (1814,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Blackheart w/Tumbler',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   6,
#   1,
#   None,
#   '93',
#   datetime.datetime(2012, 8, 1, 0, 0),
#   '96749011704',
#   '96749011704',
#   '$7.94',
#   Decimal('11.91'),
#   Decimal('47.62')),
#  (1815,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Cristall Vodka Blue Martini Gift W/glass',
#   300,
#   'Mccormick Distilling Company',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 9, 1, 0, 0),
#   None,
#   None,
#   '$12.67',
#   Decimal('19.01'),
#   Decimal('75.99')),
#  (1817,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Malibu With Cooler Jug',
#   490,
#   'Allied Domecq Spirits And Wine Usa',
#   750,
#   6,
#   1,
#   None,
#   '42',
#   datetime.datetime(2003, 6, 1, 0, 0),
#   None,
#   None,
#   '$6.93',
#   Decimal('10.40'),
#   Decimal('41.56')),
#  (18186,
#   'STRAIGHT BOURBON WHISKIES',
#   'Ezra Brooks Ky Sour Mash Bourbon',
#   434,
#   'Luxco-st Louis',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2007, 3, 1, 0, 0),
#   None,
#   None,
#   '$5.71',
#   Decimal('8.57'),
#   Decimal('68.51')),
#  (18196,
#   'STRAIGHT BOURBON WHISKIES',
#   'Ezra Brooks 50 Mo Ky Sour Mash Bourbon',
#   434,
#   'Luxco-st Louis',
#   750,
#   12,
#   1,
#   None,
#   '90',
#   datetime.datetime(1984, 11, 1, 0, 0),
#   '88352110929',
#   '10088400000000',
#   '$6.84',
#   Decimal('10.26'),
#   Decimal('82.00')),
#  (18198,
#   'STRAIGHT BOURBON WHISKIES',
#   'Ezra Brooks Ky Sour Mash Bourbon',
#   434,
#   'Luxco-st Louis',
#   1750,
#   6,
#   1,
#   None,
#   '90',
#   datetime.datetime(2005, 7, 1, 0, 0),
#   '88352110905',
#   '10088400000000',
#   '$14.34',
#   Decimal('21.51'),
#   Decimal('86.00')),
#  (18216,
#   'SINGLE BARREL BOURBON WHISKIES',
#   'Ezra B Single Barrel',
#   434,
#   'Luxco-st Louis',
#   750,
#   6,
#   1,
#   None,
#   '99',
#   datetime.datetime(2014, 6, 1, 0, 0),
#   '88352118192',
#   '10088400000000',
#   '$21.17',
#   Decimal('31.76'),
#   Decimal('127.00')),
#  (18276,
#   'STRAIGHT BOURBON WHISKIES',
#   'Fighting Cock Bourbon',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   12,
#   1,
#   None,
#   '103',
#   datetime.datetime(1998, 10, 1, 0, 0),
#   None,
#   None,
#   '$8.68',
#   Decimal('13.02'),
#   Decimal('104.16')),
#  (18277,
#   'STRAIGHT BOURBON WHISKIES',
#   'Fighting Cock Bourbon',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   1000,
#   12,
#   1,
#   None,
#   '103',
#   datetime.datetime(1998, 10, 1, 0, 0),
#   None,
#   None,
#   '$10.94',
#   Decimal('16.41'),
#   Decimal('131.23')),
#  (1829,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Ciclon Flask Pack',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '70',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$7.09',
#   Decimal('10.64'),
#   Decimal('42.54')),
#  (1833,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Ketel One Citroen Shaker Set',
#   790,
#   'Nolet Spirits Usa',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$13.36',
#   Decimal('20.04'),
#   Decimal('80.16')),
#  (18348,
#   'STRAIGHT BOURBON WHISKIES',
#   'Four Roses Small Batch',
#   184,
#   'Four Roses Distillery',
#   750,
#   6,
#   1,
#   None,
#   '90',
#   datetime.datetime(2013, 12, 1, 0, 0),
#   '40063400317',
#   '40063400300',
#   '$15.17',
#   Decimal('22.76'),
#   Decimal('91.00')),
#  (1835,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Bacardi Coco Glass Pack',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '70',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$7.53',
#   Decimal('11.30'),
#   Decimal('45.20')),
#  (18350,
#   'SINGLE BARREL BOURBON WHISKIES',
#   'Four Roses Single Barrel',
#   184,
#   'Four Roses Distillery',
#   750,
#   6,
#   1,
#   None,
#   '100',
#   datetime.datetime(2013, 12, 1, 0, 0),
#   '40063400027',
#   '18350',
#   '$20.17',
#   Decimal('30.26'),
#   Decimal('121.00')),
#  (18351,
#   'STRAIGHT BOURBON WHISKIES',
#   'Four Roses Yellow Label',
#   184,
#   'Four Roses Distillery',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2014, 12, 1, 0, 0),
#   '40063400430',
#   '40063400423',
#   '$21.95',
#   Decimal('32.93'),
#   Decimal('131.70')),
#  (18352,
#   'STRAIGHT BOURBON WHISKIES',
#   'Four Roses Yellow Label',
#   184,
#   'Four Roses Distillery',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(2014, 12, 1, 0, 0),
#   '40063400409',
#   '40063000081',
#   '$10.81',
#   Decimal('16.22'),
#   Decimal('129.70')),
#  (1836,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Bacardi Razz Glass Pack',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '70',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$7.53',
#   Decimal('11.30'),
#   Decimal('45.20')),
#  (18362,
#   'SINGLE BARREL BOURBON WHISKIES',
#   'Four Roses SB Limited Edition 2013',
#   184,
#   'Four Roses Distillery',
#   750,
#   6,
#   1,
#   None,
#   '111',
#   datetime.datetime(2012, 6, 7, 0, 0),
#   None,
#   None,
#   '$43.19',
#   Decimal('64.79'),
#   Decimal('259.14')),
#  (1837,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Bacardi Vanilla Glass Pack',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '70',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$7.53',
#   Decimal('11.30'),
#   Decimal('45.20')),
#  (1838,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Malibu w/Dole Pineapple Juice',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1750,
#   3,
#   1,
#   None,
#   '42',
#   datetime.datetime(2014, 8, 1, 0, 0),
#   '89540496054',
#   '10089500000000',
#   '$16.49',
#   Decimal('24.74'),
#   Decimal('49.47')),
#  (18406,
#   'STRAIGHT BOURBON WHISKIES',
#   'G&w Private Stock 4 Yr Str Bourbon',
#   297,
#   'Laird And Company',
#   750,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(1974, 5, 1, 0, 0),
#   None,
#   None,
#   '$4.00',
#   Decimal('6.00'),
#   Decimal('48.03')),
#  (18407,
#   'STRAIGHT BOURBON WHISKIES',
#   'G & W Bourbon',
#   297,
#   'Laird And Company',
#   1000,
#   12,
#   1,
#   None,
#   '80',
#   datetime.datetime(1988, 8, 1, 0, 0),
#   '84848200204',
#   '10084800000000',
#   '$4.94',
#   Decimal('7.41'),
#   Decimal('59.22')),
#  (18408,
#   'STRAIGHT BOURBON WHISKIES',
#   'G & W Bourbon',
#   297,
#   'Laird And Company',
#   1750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(1977, 8, 1, 0, 0),
#   '84848200105',
#   '10084800000000',
#   '$9.23',
#   Decimal('13.85'),
#   Decimal('55.38')),
#  (1841,
#   'FLAVORED VODKA',
#   'Skyy Rainbow Pack',
#   461,
#   'Campari(skyy)',
#   750,
#   12,
#   1,
#   None,
#   '70',
#   datetime.datetime(2003, 5, 1, 0, 0),
#   None,
#   None,
#   '$9.49',
#   Decimal('14.24'),
#   Decimal('113.84')),
#  (1846,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Ketel One Shaker Set',
#   260,
#   'Diageo Americas',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$13.47',
#   Decimal('20.21'),
#   Decimal('80.84')),
#  (185,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Bookers Bourbon W/leather Cigar Case',
#   65,
#   'Jim Beam Brands',
#   750,
#   6,
#   1,
#   None,
#   '125',
#   datetime.datetime(1997, 10, 1, 0, 0),
#   None,
#   None,
#   '$26.79',
#   Decimal('40.19'),
#   Decimal('160.76')),
#  (1852,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Beefeater W/2 Rocks Glasses',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1750,
#   6,
#   1,
#   None,
#   '94',
#   datetime.datetime(2005, 8, 1, 0, 0),
#   None,
#   None,
#   '$21.55',
#   Decimal('32.33'),
#   Decimal('129.28')),
#  (1855,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Beefeater w/Yeoman Pourer',
#   370,
#   'Pernod Ricard Usa/austin Nichols',
#   1750,
#   6,
#   1,
#   None,
#   '94',
#   datetime.datetime(2013, 10, 1, 0, 0),
#   '89540510811',
#   '10089500000000',
#   '$21.99',
#   Decimal('32.99'),
#   Decimal('131.94')),
#  (1857,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Grey Goose Vodka Pewter Stemmed Martini Glass',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$16.77',
#   Decimal('25.16'),
#   Decimal('100.60')),
#  (18576,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Henry Mckenna Special Reserve Jug',
#   259,
#   'Heaven Hill Distilleries Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(1995, 10, 1, 0, 0),
#   None,
#   None,
#   '$11.76',
#   Decimal('17.64'),
#   Decimal('70.55')),
#  (1858,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Grey Goose Le Citron W/pewter Stemmed Glass',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$16.13',
#   Decimal('24.20'),
#   Decimal('96.75')),
#  (1859,
#   'DECANTERS & SPECIALTY PACKAGES',
#   "Grey Goose L'orange Pewter Stemmed Martini Gl",
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$16.77',
#   Decimal('25.16'),
#   Decimal('100.60')),
#  (1860,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Grey Goose La Vanille W/pewter Stemmed Glass',
#   35,
#   'Bacardi U.s.a. Inc.',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$16.13',
#   Decimal('24.20'),
#   Decimal('96.75')),
#  (1863,
#   'DECANTERS & SPECIALTY PACKAGES',
#   'Belvedere W/shot Glass & Serving Bowl',
#   852,
#   'Millennium Import Company',
#   750,
#   6,
#   1,
#   None,
#   '80',
#   datetime.datetime(2003, 8, 1, 0, 0),
#   None,
#   None,
#   '$15.40',
#   Decimal('23.10'),
#   Decimal('92.39'))]

# %% [markdown]
# Excellent! Let's scrape the web now! (this means- get the html behind the scenes and parse it)! FIRST let's grab data from this website: http://www.boxofficemojo.com/weekend/
# So- obviously this baby is key for anyone in the entertainment business, right? Okay, so...let's go to that site and take a look at the element that we want to grab.
# Looking at this we can see the element that we are looking for is "mrc main table"
# OKAY- as with everything in python- we want a library to deal with! A little googling will show us that the appropriate library is one known as "BeautifulSoup" so let's grab that one and we're off to the races!

# %%
# !pip install BeautifulSoup
# Out:
# Collecting BeautifulSoup
#   Downloading BeautifulSoup-3.2.1.tar.gz
# Building wheels for collected packages: BeautifulSoup
# done
#   Stored in directory: /Users/fpombeiro/Library/Caches/pip/wheels/5e/be/6d/ed01d5d434a821557b674c9da976f60b1b93d9009447eb9d16
# Successfully built BeautifulSoup
# Installing collected packages: BeautifulSoup
# Successfully installed BeautifulSoup-3.2.1

# %% [markdown]
# We'll also want a module called "requests" that comes with python, so:

# %%
import requests
from BeautifulSoup import BeautifulSoup

# %% [markdown]
# Let's write out our url (copy and paste):

# %%
url = 'http://www.boxofficemojo.com/weekend/'

# %% [markdown]
# Now let's go to the website and grab the data...

# %%
response = requests.get(url)

# %% [markdown]
# Okay so now we want to get the html behind this...

# %%
html = response.content

# %% [markdown]
# Okay- so now we are looking to go through that string and find what we're looking for. The good news is that the "BeautifulSoup" library helps us with that...so let's put that html into the library.

# %%
soup = BeautifulSoup(html)

# %% [markdown]
# Okay- so now we want to traverse this site- go through and pick up all of the key elements which we are looking for (in this case- box office stuff!)

# %%
table = soup.find('table', attrs={'border': '0', 'cellspacing': '1', 'cellpadding': '5'})

# %% [markdown]
# Okay- confirm that we have the right table:

# %%
table.prettify()
# Out:
# '<table border="0" cellspacing="1" cellpadding="5">\n<tr bgcolor="#dcdcdc">\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=date&amp;order=DESC&amp;p=.htm">\n    Weekend\n    <br />\n    (Click to view)\n   </a>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=top12&amp;order=DESC&amp;p=.htm">\n    Top 12 Gross\n   </a>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=top12change&amp;order=DESC&amp;p=.htm">\n    Change\n    <br />\n    LW\n   </a>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=sumgross&amp;order=DESC&amp;p=.htm">\n    Overall Gross\n   </a>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=sumchange&amp;order=DESC&amp;p=.htm">\n    Change\n    <br />\n    LW\n   </a>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=nummovies&amp;order=DESC&amp;p=.htm">\n    Total\n    <br />\n    Movies\n   </a>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=num1movie&amp;order=ASC&amp;p=.htm">\n    #1 Movie\n   </a>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="1">\n   <a href="/weekend/?yr=2016&amp;sort=weeknum&amp;order=ASC&amp;p=.htm">\n    Week\n   </a>\n  </font>\n </td>\n</tr>\n<tr bgcolor="#ffffff">\n <td nowrap="nowrap">\n  <font face="Arial" size="2">\n   <a href="/weekend/chart/?yr=2016&amp;wknd=52a&amp;p=.htm">\n    <b>\n     <i>\n      Dec. 23&#150;26\n     </i>\n    </b>\n   </a>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <i>\n    $259,821,566\n   </i>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <i>\n    -\n   </i>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <i>\n    $274,555,615\n   </i>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <i>\n    -\n   </i>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <i>\n    59\n   </i>\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="2">\n   <i>\n    <font size="1">\n     <a href="/movies/?page=weekend&amp;id=starwars2016.htm">\n      Rogue One\n     </a>\n    </font>\n   </i>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <i>\n    <a href="/weekend/?view=wknd&amp;wknd=52&amp;sort=&amp;order=DESC&amp;&amp;p=.htm">\n     52\n    </a>\n   </i>\n  </font>\n </td>\n</tr>\n<tr bgcolor="#ffff99">\n <td nowrap="nowrap">\n  <font face="Arial" size="2">\n   <a href="/weekend/chart/?yr=2016&amp;wknd=52&amp;p=.htm">\n    <b>\n     Dec. 23&#150;25\n    </b>\n   </a>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   $171,367,755\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <font color="#ff0000">\n    -16.9%\n   </font>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   $181,155,083\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <font color="#ff0000">\n    -14.4%\n   </font>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   69\n  </font>\n </td>\n <td align="center">\n  <font face="Arial" size="2">\n   <font size="1">\n    <a href="/movies/?page=weekend&amp;id=starwars2016.htm">\n     Rogue One\n    </a>\n   </font>\n  </font>\n </td>\n <td align="right">\n  <font face="Arial" size="2">\n   <a href="/weekend/?view=wknd&amp;wknd=52&amp;sort=&amp;order=DESC&amp;&amp;p=.htm">\n    52\n   </a>\n  </font>\n </td>\n</tr>\n<tr bgcolor="#ffffff">\n <td nowrap="nowrap">\n  <font face="Arial" size="2">\n   <a href="/weekend/chart/?yr=2016&amp;wknd=51&amp;p=.htm">\n    <b>\n     Dec. 16&#150;18\n    </b>\n   </a>\n  </fo ...

# %% [markdown]
# Excellent! Now we know what we are looking for...So our next mission is to traverse it and pick out the totals. In this case it looks like it's laid out as a <tr> then a bunch of <td> so let's try this:

# %%
for each in table.findAll('tr'):
    for row in each.findChildren('td'):
        for number in row.findChildren('i'):
            print number.text
# Out:
# Dec. 23&#150;26
# $259,821,566
# -
# $274,555,615
# -
# 59
# Rogue One
# 52
# Sep. 2&#150;5
# $95,620,250
# -
# $128,342,610
# -
# 94
# Don't Breathe
# 36
# Jul. 1&#150;4
# $220,896,658
# -
# $231,133,020
# -
# 81
# Finding Dory
# 27
# May 27&#150;30
# $198,872,015
# -
# $205,463,282
# -
# 83
# X-Men: Apocalypse
# 22
# Feb. 12&#150;15
# $257,523,733
# -
# $278,484,327
# -
# 87
# Deadpool
# 7
# Jan. 15&#150;18
# $183,172,124
# -
# $200,456,940
# -
# 54
# Ride Along 2
# 3

# %% [markdown]
# And now if we wanted to write this to a csv every day it would be pretty easy- we could use the 'csv.write' module the same way that we did before and voila!

# %% [markdown]
# Now let's talk about the last way to get data- through an API! SO...there's a great free API that does currency conversion here: http://api.fixer.io/latest?base=USD
# It basically looks each day and returns the exchange rate against anything. We can also look historically (the documentation is all here: http://fixer.io/
# SO...check it out and build an api call that takes a date as input and spits out the latest currency. Can you do it? Make it a function...
